# %%
import os

import wave
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from IPython.display import Audio

import librosa
import librosa.display

from keras.utils import np_utils
from keras.layers import concatenate
from tensorflow.keras.models import Sequential, Model, load_model

from tensorflow.keras.layers import Conv1D, Conv2D, SeparableConv1D, MaxPooling1D, MaxPooling2D
from tensorflow.keras.layers import Input, add, Flatten, Dense, BatchNormalization, Dropout, LSTM, GRU
from tensorflow.keras.layers import GlobalMaxPooling1D, GlobalMaxPooling2D, Activation, LeakyReLU, ReLU

# from tensorflow.keras.layers import Embedding,LSTM,GRU,Dense,MaxPooling1D,Dropout, Input
# from tensorflow.keras.layers import LeakyReLU,ReLU,Flatten,concatenate,Bidirectional,TimeDistributed 
# from tensorflow.keras.layers import add,Conv1D,SeparableConv1D, GlobalMaxPooling2D,GlobalMaxPooling1D
# from tensorflow.keras.layers import Conv2D,Input,Activation,BatchNormalization,MaxPooling2D

from tensorflow.keras import regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef
from sklearn.metrics import cohen_kappa_score,roc_auc_score,confusion_matrix,classification_report

# %%
audio_data = 'D:/Visual Studio Code/AI Project/input/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/'

# %%
patient_data=pd.read_csv('D:\Visual Studio Code\AI Project\input\Respiratory_Sound_Database\Respiratory_Sound_Database\patient_diagnosis.csv',names=['pid','disease'])

# %%
diagnosis_df = pd.read_csv('D:\Visual Studio Code\AI Project\input\Respiratory_Sound_Database\Respiratory_Sound_Database\patient_diagnosis.csv', names=['patient_id', 'disease'])
diagnosis_df.head(4)
# Out:
#    patient_id  disease
# 0         101     URTI
# 1         102  Healthy
# 2         103   Asthma
# 3         104     COPD

# %%
print (diagnosis_df.disease.value_counts())
print ('')
print (diagnosis_df.disease.value_counts(normalize=True) *100)
# Out:
# disease
# COPD              64
# Healthy           26
# URTI              14
# Bronchiectasis     7
# Pneumonia          6
# Bronchiolitis      6
# LRTI               2
# Asthma             1
# Name: count, dtype: int64
#
# disease
# COPD              50.793651
# Healthy           20.634921
# URTI              11.111111
# Bronchiectasis     5.555556
# Pneumonia          4.761905
# Bronchiolitis      4.761905
# LRTI               1.587302
# Asthma             0.793651
# Name: proportion, dtype: float64

# %%
counts = diagnosis_df['disease'].value_counts()

sns.barplot(x=counts.index, y=counts.values, color='blue')  # You can change the color as needed
plt.grid(axis='y', color='green', linestyle='--', linewidth=0.5)
plt.xticks(rotation=90)
plt.show()
# Out:
# c:\Users\Acer\anaconda3\envs\ForReal\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Acer\anaconda3\envs\ForReal\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Acer\anaconda3\envs\ForReal\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
path= r'D:\Visual Studio Code\AI Project\input\Respiratory_Sound_Database\Respiratory_Sound_Database\audio_and_txt_files'
files=[s.split('.')[0] for s in os.listdir(path) if '.txt' in s]

# %%
files[:10]
# Out:
# ['101_1b1_Al_sc_Meditron',
#  '101_1b1_Pr_sc_Meditron',
#  '102_1b1_Ar_sc_Meditron',
#  '103_2b2_Ar_mc_LittC2SE',
#  '104_1b1_Al_sc_Litt3200',
#  '104_1b1_Ar_sc_Litt3200',
#  '104_1b1_Ll_sc_Litt3200',
#  '104_1b1_Lr_sc_Litt3200',
#  '104_1b1_Pl_sc_Litt3200',
#  '104_1b1_Pr_sc_Litt3200']

# %%
def add_noise(data,x):
    noise = np.random.randn(len(data))
    data_noise = data + x * noise
    return data_noise

def shift(data,x):
    return np.roll(data, x)

def stretch(data, rate):
    data = librosa.effects.time_stretch(data, rate)
    return data

def pitch_shift (data , rate):
    data = librosa.effects.pitch_shift(data, sr=220250, n_steps=rate)
    return data

# %%
def show_audio(audio_path):
    y, sr = librosa.load(audio_path)
    y_noise = add_noise(y , 0.0008)
    y_shift = shift(y,3200)
    y_stretch_1 = stretch(y, 1.2)
    y_stretch_2 = stretch(y, 0.8)
    y_pitch_shift = pitch_shift(y, 3)
    
    plt.figure(figsize=(20, 8))
    
    plt.subplot(3,2,1)
    librosa.display.waveshow(y, sr=sr)
    plt.title('orginal')

    plt.subplot(3,2,2)
    librosa.display.waveshow(y_noise, sr=sr)
    plt.title('noise')

    plt.subplot(3,2,3)
    librosa.display.waveshow(y_shift, sr=sr)
    plt.title('shift')
    
    plt.subplot(3,2,4)
    librosa.display.waveshow(y_stretch_1, sr=sr)
    plt.title('stretch 1')
    
    plt.subplot(3,2,5)
    librosa.display.waveshow(y_stretch_2, sr=sr)
    plt.title('stretch 2')
    
    plt.subplot(3,2,6)
    librosa.display.waveshow(y_pitch_shift, sr=sr)
    plt.title('pitch shift')

    plt.tight_layout()

def stretch(data, rate):
    try:
        # Newer librosa versions
        data_stretched = librosa.effects.time_stretch(data, rate)
    except TypeError:
        # Older librosa versions
        data_stretched = librosa.effects.time_stretch(data, rate=rate)
    return data_stretched

# %%
def show_audio_features(audio_path):
    y, sr = librosa.load(audio_path)
    y_noise = add_noise(y , 0.0008)
    y_shift = shift(y,3200)
    y_stretch_1 = stretch(y, 1.2)
    y_stretch_2 = stretch(y, 0.8)
    y_pitch_shift = pitch_shift(y, 3)
    
    y = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=50)
    y_noise = librosa.feature.mfcc(y=y_noise, sr=sr, n_mfcc=50)
    y_shift = librosa.feature.mfcc(y=y_shift, sr=sr, n_mfcc=50)
    y_stretch_1 = librosa.feature.mfcc(y=y_stretch_1, sr=sr, n_mfcc=50)
    y_stretch_2 = librosa.feature.mfcc(y=y_stretch_2, sr=sr, n_mfcc=50)
    y_pitch_shift = librosa.feature.mfcc(y=y_pitch_shift, sr=sr, n_mfcc=50)
    
    plt.figure(figsize=(20, 8))
    
    plt.subplot(3,2,1)
    librosa.display.specshow(librosa.power_to_db(y,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('orginal')

    plt.subplot(3,2,2)
    librosa.display.specshow(librosa.power_to_db(y_noise,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('noise')

    plt.subplot(3,2,3)
    librosa.display.specshow(librosa.power_to_db(y_shift,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('shift')
    
    plt.subplot(3,2,4)
    librosa.display.specshow(librosa.power_to_db(y_stretch_1,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('stretch 1')
    
    plt.subplot(3,2,5)
    librosa.display.specshow(librosa.power_to_db(y_stretch_2,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('stretch 2')
    
    plt.subplot(3,2,6)
    librosa.display.specshow(librosa.power_to_db(y_pitch_shift,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('pitch shift')
    
    

    plt.tight_layout()

# %%
show_audio('D:/Visual Studio Code/AI Project/input/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Lr_sc_Litt3200.wav')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 show_audio('D:/Visual Studio Code/AI Project/input/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Lr_sc_Litt3200.wav')
#
# Cell In[13], line 12, in show_audio(audio_path)
#       9 plt.figure(figsize=(20, 8))
#      11 plt.subplot(3,2,1)
# ---> 12 librosa.display.waveshow(y, sr=sr)
#      13 plt.title('orginal')
#      15 plt.subplot(3,2,2)
#
# File c:\Users\Acer\anaconda3\envs\ForReal\lib\site-packages\librosa\display.py:2042, in waveshow(y, sr, max_points, axis, offset, marker, where, label, transpose, ax, x_axis, **kwargs)
#    2032 axis = rename_kw(
#    2033     old_name="x_axis",
#    2034     old_value=x_axis,
#    (...)
#    2038     version_removed="1.0",
#    2039 )
#    2041 if "color" not in kwargs:
# -> 2042     kwargs.setdefault("color", next(axes._get_lines.prop_cycler)["color"])
#    2044 # Reduce by envelope calculation
#    2045 # this choice of hop ensures that the envelope has at most max_points values
#    2046 hop_length = max(1, y.shape[-1] // max_points)
#
# AttributeError: '_process_plot_var_args' object has no attribute 'prop_cycler'

# %%
show_audio_features('D:/Visual Studio Code/AI Project/input/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Lr_sc_Litt3200.wav')

# %%
def mfccs_feature_exteraction(dir_):
    '''
        Extract MFCC feature from the Sound data from the audio data. 
        Augmentation of sound data by adding Noise, streaching and shifting.
        50 features are extracted from each audio data and used to train the model. 
        Also, we remove .wav files with patient_id 103,108, and 115 to solve data imbalance, because they have unique lables. 
        
        Args: dir_: Input directory to the Sound input file.
        
        Returns:
            X_data: Array of features extracted from the sound file.
            y_data: Array of target Labels.
    '''
    X_=[]
    y_=[]
    
    COPD=[]
    copd_count=0
    
    data = diagnosis_df
    features = 52
    
    for soundDir in (os.listdir(dir_)):
        if soundDir[-3:]=='wav'and soundDir[:3]!='103'and soundDir[:3]!='108'and soundDir[:3]!='115':

            p = list(data[data['patient_id']==int(soundDir[:3])]['disease'])[0]
            if (p=='COPD'):
                if (soundDir[:6] in COPD) and copd_count<2:
                    data_x, sampling_rate = librosa.load(dir_+soundDir,res_type='kaiser_fast')
                    mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    COPD.append(soundDir[:6])
                    copd_count+=1
                    X_.append(mfccs)
                    y_.append(list(data[data['patient_id']==int(soundDir[:3])]['disease'])[0])
                    
                if (soundDir[:6] not in COPD):
                    data_x, sampling_rate = librosa.load(dir_+soundDir,res_type='kaiser_fast')
                    mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    COPD.append(soundDir[:6])
                    copd_count=0
                    X_.append(mfccs)
                    y_.append(list(data[data['patient_id']==int(soundDir[:3])]['disease'])[0])
                
            if (p!='COPD'):
                if ((p == 'Bronchiectasis') or (p == 'Bronchiolitis')):
                    data_x, sampling_rate = librosa.load(dir_+soundDir,res_type='kaiser_fast')
                    mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs)
                    y_.append('Bronchiolitis')
            
                    data_noise = add_noise(data_x,0.001)
                    mfccs_noise = np.mean(librosa.feature.mfcc(y=data_noise, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_noise)
                    y_.append('Bronchiolitis')

                    data_shift = shift(data_x,1600)
                    mfccs_shift = np.mean(librosa.feature.mfcc(y=data_shift, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_shift)
                    y_.append('Bronchiolitis')
                    
                    data_stretch = stretch(data_x,1.2)
                    mfccs_stretch = np.mean(librosa.feature.mfcc(y=data_stretch, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_stretch)
                    y_.append('Bronchiolitis')
                    
                    data_stretch_2 = stretch(data_x,0.8)
                    mfccs_stretch_2 = np.mean(librosa.feature.mfcc(y=data_stretch_2, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_stretch_2)
                    y_.append('Bronchiolitis')
                    
                    data_pitch_shift = pitch_shift(data_x,3)
                    mfccs_stretch = np.mean(librosa.feature.melspectrogram(y=data_pitch_shift, sr=sampling_rate, n_mels=features).T,axis=0)
                    X_.append(mfccs_stretch)
                    y_.append('Bronchiolitis')
                    
                else: 
                    data_x, sampling_rate = librosa.load(dir_+soundDir,res_type='kaiser_fast')
                    mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs)
                    y_.append(list(data[data['patient_id']==int(soundDir[:3])]['disease'])[0])
            
                    data_noise = add_noise(data_x,0.001)
                    mfccs_noise = np.mean(librosa.feature.mfcc(y=data_noise, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_noise)
                    y_.append(p)

                    data_shift = shift(data_x,1600)
                    mfccs_shift = np.mean(librosa.feature.mfcc(y=data_shift, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_shift)
                    y_.append(p)
                    
                    data_stretch = stretch(data_x,1.2)
                    mfccs_stretch = np.mean(librosa.feature.mfcc(y=data_stretch, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_stretch)
                    y_.append(p)
                    
                    data_stretch_2 = stretch(data_x,0.8)
                    mfccs_stretch_2 = np.mean(librosa.feature.mfcc(y=data_stretch_2, sr=sampling_rate, n_mfcc=features).T,axis=0)
                    X_.append(mfccs_stretch_2)
                    y_.append(p)
                    
                    data_pitch_shift = pitch_shift(data_x,3)
                    mfccs_stretch = np.mean(librosa.feature.melspectrogram(y=data_pitch_shift, sr=sampling_rate, n_mels=features).T,axis=0)
                    X_.append(mfccs_stretch)
                    y_.append(p)
                    
                    
                
    X_data = np.array(X_)
    y_data = np.array(y_)

    
    return X_data, y_data

# %%
x_mfccs, y = mfccs_feature_exteraction(audio_data)

# %%
def augmented_lables_count(lables):
    unique, counts = np.unique(lables, return_counts=True)
    data_count = dict(zip(unique, counts))

    data = data_count

    courses = list(data.keys())
    values = list(data.values())

    fig = plt.figure(figsize = (10, 5))

    # creating the bar plot
    plt.bar(courses, values, color =['orange','green','blue','red','yellow','black'],
            width = 0.4)

    plt.xlabel("Diseases")
    plt.ylabel("Count")
    plt.title("Count of each disease")
    plt.show()

    print (data_count)

# %%
augmented_lables_count(y)
# Out:
# {'Bronchiolitis': 174, 'COPD': 298, 'Healthy': 210, 'Pneumonia': 222, 'URTI': 138}

# %%
y_data_encode = y.reshape(y.shape[0],1)
y_data_encode = np.where(y_data_encode == 'COPD',np.array([1,0,0,0,0]).reshape(1,5) , y_data_encode)
y_data_encode = np.where(y_data_encode == 'Bronchiolitis',np.array([0,1,0,0,0]).reshape(1,5) , y_data_encode)
y_data_encode = np.where(y_data_encode == 'Pneumonia',np.array([0,0,1,0,0]).reshape(1,5) , y_data_encode)
y_data_encode = np.where(y_data_encode == 'URTI',np.array([0,0,0,1,0]).reshape(1,5) , y_data_encode)
y_data_encode = np.where(y_data_encode == 'Healthy',np.array([0,0,0,0,1]).reshape(1,5) , y_data_encode)

Y_data = y_data_encode.astype('float64')

# %%
mfccs_features = np.array(x_mfccs)
lables = np.array(Y_data)

mfccs_features.shape , lables.shape
# Out:
# ((1042, 52), (1042, 5))

# %%
mfcc_train, mfcc_val, lables_train, lables_val  = train_test_split(mfccs_features, lables, test_size=0.175, random_state=10)
mfcc_train, mfcc_test, lables_train, lables_test = train_test_split(mfcc_train, lables_train, test_size=0.075, random_state=10)

print (mfcc_train.shape, mfcc_val.shape, mfcc_test.shape)
print (lables_train.shape, lables_val.shape, lables_test.shape)
# Out:
# (794, 52) (183, 52) (65, 52)
# (794, 5) (183, 5) (65, 5)

# %%
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  Args:
    history: TensorFlow model History object (see: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History)
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
#   plt.plot(epochs, loss, label='training_loss')
#   plt.plot(epochs, val_loss, label='val_loss')
#   plt.title('Loss')
#   plt.xlabel('Epochs')
#   plt.legend()
#   plt.grid()


  # Plot accuracy
  plt.figure()
  plt.grid()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
x_train_gru = np.expand_dims(mfcc_train,axis=1)
x_val_gru = np.expand_dims(mfcc_val,axis=1)
x_test_gru = np.expand_dims(mfcc_test,axis=1)

y_train_gru = np.expand_dims(lables_train,axis=1)
y_val_gru = np.expand_dims(lables_val,axis=1)
y_test_gru = np.expand_dims(lables_test,axis=1)

# %%
Input_Sample = Input(shape=(1,52))

model_conv = Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu')(Input_Sample)
model_conv = MaxPooling1D(pool_size=2, strides = 2, padding = 'same')(model_conv)
model_conv = BatchNormalization()(model_conv)

model_conv = Conv1D(512, kernel_size=5, strides=1, padding='same', activation='relu')(model_conv)
model_conv = MaxPooling1D(pool_size=2, strides = 2, padding = 'same')(model_conv)
model_conv = BatchNormalization()(model_conv)

model_2_1 = GRU(32,return_sequences=True,activation='tanh',go_backwards=True)(model_conv)
model_2 = GRU(128,return_sequences=True, activation='tanh',go_backwards=True)(model_2_1)

model_3 = GRU(64,return_sequences=True,activation='tanh',go_backwards=True)(model_conv)
model_3 = GRU(128,return_sequences=True, activation='tanh',go_backwards=True)(model_3)

model_x = GRU(64,return_sequences=True,activation='tanh',go_backwards=True)(model_conv)
model_x = GRU(128,return_sequences=True, activation='tanh',go_backwards=True)(model_x)

model_add_1 = add([model_3,model_2,model_x])

model_5 = GRU(128,return_sequences=True,activation='tanh',go_backwards=True)(model_add_1)
model_5 = GRU(32,return_sequences=True, activation='tanh',go_backwards=True)(model_5)

model_6 = GRU(64,return_sequences=True,activation='tanh',go_backwards=True)(model_add_1)
model_6 = GRU(32,return_sequences=True, activation='tanh',go_backwards=True)(model_6)

model_add_2 = add([model_5,model_6,model_2_1])


model_7 = Dense(32, activation=None)(model_add_2)
model_7 = LeakyReLU()(model_7)
model_7 = Dense(128, activation=None)(model_7)
model_7 = LeakyReLU()(model_7)

model_9 = Dense(64, activation=None)(model_add_2)
model_9 = LeakyReLU()(model_9)
model_9 = Dense(128, activation=None)(model_9)
model_9 = LeakyReLU()(model_9)

model_add_3 = add([model_7,model_9])

model_10 = Dense(64, activation=None)(model_add_3)
model_10 = LeakyReLU()(model_10)

model_10 = Dense(32, activation=None)(model_10)
model_10 = LeakyReLU()(model_10)

model_10 = Dense(5, activation="softmax")(model_10)

gru_model = Model(inputs=Input_Sample, outputs = model_10)

gru_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1, 52)]      0           []
#
#  conv1d (Conv1D)                (None, 1, 256)       66816       ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 1, 256)       0           ['conv1d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1, 256)      1024        ['max_pooling1d[0][0]']
#  alization)
#
#  conv1d_1 (Conv1D)              (None, 1, 512)       655872      ['batch_normalization[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 1, 512)      0           ['conv1d_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 1, 512)      2048        ['max_pooling1d_1[0][0]']
#  rmalization)
#
#  gru_2 (GRU)                    (None, 1, 64)        110976      ['batch_normalization_1[0][0]']
#
#  gru (GRU)                      (None, 1, 32)        52416       ['batch_normalization_1[0][0]']
#
#  gru_4 (GRU)                    (None, 1, 64)        110976      ['batch_normalization_1[0][0]']
#
#  gru_3 (GRU)                    (None, 1, 128)       74496       ['gru_2[0][0]']
#
#  gru_1 (GRU)                    (None, 1, 128)       62208       ['gru[0][0]']
#
#  gru_5 (GRU)                    (None, 1, 128)       74496       ['gru_4[0][0]']
#
#  add (Add)                      (None, 1, 128)       0           ['gru_3[0][0]',
#                                                                   'gru_1[0][0]',
#                                                                   'gru_5[0][0]']
#
#  gru_6 (GRU)                    (None, 1, 128)       99072       ['add[0][0]']
#
#  gru_8 (GRU)                    (None, 1, 64)        37248       ['add[0][0]']
#
#  gru_7 (GRU)                    (None, 1, 32)        15552       ['gru_6[0][0]']
#
#  gru_9 (GRU)                    (None, 1, 32)        9408        ['gru_8[0][0]']
#
#  add_1 (Add)                    (None, 1, 32)        0           ['gru_7[0][0]',
#                                                                   'gru_9[0][0]',
#                                                                   'gru[0][0]']
#
#  dense (Dense)                  (None, 1, 32)        1056        ['add_1[0][0]']
#
#  dense_2 (Dense)                (None, 1, 64)        2112        ['add_1[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 1, 32)        0           ['dense[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 1, 64)        0           ['dense_2[0][0]']
#
#  dense_1 (Dense)                (None, 1, 128)       4224        ['leaky_re_lu[0][0]']
#
#  dense_3 (Dense)                (None, 1, 128)       8320        ['leaky_re_lu_2[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 1, 128)       0           ['dense_1[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 1, 128)       0           ['dense_3[0][0]']
#
#  add_2 (Add)                    (None, 1, 128)       0           ['leaky_re_lu_1[0][0]',
#                                                                   'leaky_re_lu_3[0][0]']
#
#  dense_4 (Dense)                (None, 1, 64)        8256        ['add_2[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 1, 64)        0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 1, 32)        2080        ['leaky_re_lu_4[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 1, 32)        0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 1, 5)         165         ['leaky_re_lu_5[0][0]']
#
# ==================================================================================================
# Total params: 1,398,821
# Trainable params: 1,397,285
# Non-trainable params: 1,536
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(gru_model, "gru_model.png", show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
optimiser = tf.keras.optimizers.Adam(learning_rate = 0.0001)
gru_model.compile(optimizer=optimiser, loss='categorical_crossentropy',metrics=['accuracy'])

cb = [EarlyStopping(patience=300,monitor='accuracy',mode='max',restore_best_weights=True),
      ModelCheckpoint("/kaggle/working/diagnosis_GRU_CNN_1.h5",save_best_only=True)]

# %%
history = gru_model.fit(x_train_gru, y_train_gru, batch_size=8, epochs=50, validation_data=(x_val_gru, y_val_gru), callbacks = cb)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 44s 123ms/step - loss: 1.4288 - accuracy: 0.4030 - val_loss: 1.4555 - val_accuracy: 0.4645
# Epoch 2/50
# 100/100 [==============================] - 4s 41ms/step - loss: 1.2051 - accuracy: 0.5390 - val_loss: 1.2513 - val_accuracy: 0.5683
# Epoch 3/50
# 100/100 [==============================] - 4s 41ms/step - loss: 1.0600 - accuracy: 0.5894 - val_loss: 1.0638 - val_accuracy: 0.6120
# Epoch 4/50
# 100/100 [==============================] - 4s 45ms/step - loss: 0.9642 - accuracy: 0.6196 - val_loss: 0.8877 - val_accuracy: 0.6448
# Epoch 5/50
# 100/100 [==============================] - 4s 37ms/step - loss: 0.9103 - accuracy: 0.6448 - val_loss: 0.7963 - val_accuracy: 0.6831
# Epoch 6/50
# 100/100 [==============================] - 3s 32ms/step - loss: 0.8592 - accuracy: 0.6524 - val_loss: 0.7998 - val_accuracy: 0.6557
# Epoch 7/50
# 100/100 [==============================] - 4s 44ms/step - loss: 0.8473 - accuracy: 0.6700 - val_loss: 0.7785 - val_accuracy: 0.7158
# Epoch 8/50
# 100/100 [==============================] - 5s 46ms/step - loss: 0.7912 - accuracy: 0.6877 - val_loss: 0.7385 - val_accuracy: 0.6831
# Epoch 9/50
# 100/100 [==============================] - 5s 45ms/step - loss: 0.7814 - accuracy: 0.6851 - val_loss: 0.7144 - val_accuracy: 0.6721
# Epoch 10/50
# 100/100 [==============================] - 5s 46ms/step - loss: 0.7324 - accuracy: 0.7116 - val_loss: 0.6947 - val_accuracy: 0.6831
# Epoch 11/50
# 100/100 [==============================] - 3s 28ms/step - loss: 0.7608 - accuracy: 0.7078 - val_loss: 0.8038 - val_accuracy: 0.6393
# Epoch 12/50
# 100/100 [==============================] - 4s 35ms/step - loss: 0.7322 - accuracy: 0.7141 - val_loss: 0.8788 - val_accuracy: 0.6120
# Epoch 13/50
# 100/100 [==============================] - 3s 35ms/step - loss: 0.7276 - accuracy: 0.6940 - val_loss: 0.6986 - val_accuracy: 0.6885
# Epoch 14/50
# 100/100 [==============================] - 5s 48ms/step - loss: 0.7481 - accuracy: 0.7040 - val_loss: 0.6336 - val_accuracy: 0.7268
# Epoch 15/50
# 100/100 [==============================] - 5s 48ms/step - loss: 0.6689 - accuracy: 0.7217 - val_loss: 0.5918 - val_accuracy: 0.7486
# Epoch 16/50
# 100/100 [==============================] - 3s 29ms/step - loss: 0.7000 - accuracy: 0.7154 - val_loss: 0.6019 - val_accuracy: 0.7432
# Epoch 17/50
# 100/100 [==============================] - 5s 47ms/step - loss: 0.6524 - accuracy: 0.7355 - val_loss: 0.5596 - val_accuracy: 0.7869
# Epoch 18/50
# 100/100 [==============================] - 3s 32ms/step - loss: 0.6467 - accuracy: 0.7380 - val_loss: 0.5997 - val_accuracy: 0.7486
# Epoch 19/50
# 100/100 [==============================] - 3s 34ms/step - loss: 0.6479 - accuracy: 0.7368 - val_loss: 0.6390 - val_accuracy: 0.7596
# Epoch 20/50
# 100/100 [==============================] - 4s 36ms/step - loss: 0.6325 - accuracy: 0.7519 - val_loss: 0.6109 - val_accuracy: 0.7760
# Epoch 21/50
# 100/100 [==============================] - 3s 35ms/step - loss: 0.6076 - accuracy: 0.7594 - val_loss: 0.5756 - val_accuracy: 0.7596
# Epoch 22/50
# 100/100 [==============================] - 4s 35ms/step - loss: 0.6266 - accuracy: 0.7519 - val_loss: 0.5858 - val_accuracy: 0.7432
# Epoch 23/50
# 100/100 [==============================] - 3s 32ms/step - loss: 0.5954 - accuracy: 0.7620 - val_loss: 0.5984 - val_accuracy: 0.7760
# Epoch 24/50
# 100/100 [==============================] - 3s 34ms/step - loss: 0.5836 - accuracy: 0.7834 - val_loss: 0.5885 - val_accuracy: 0.7377
# Epoch 25/50
# 100/100 [==============================] - 5s 45ms/step - loss: 0.5585 - accuracy: 0.7695 - val_loss: 0.5175 - val_accuracy: 0.7705
# Epoch 26/50
# 100/100 [==============================] - 3s 31ms/step - loss: 0.5814 - accuracy: 0.7645 - val_loss: 0.5470 - val_accuracy: 0.7869
# Epoch 27/50
# 100/100 [==============================] - 4s 44ms/step - loss: 0.5699 - accuracy: 0.7683 - val_loss: 0.4882 - val_accuracy: 0.8142
# Epoch 28/50
# 100/100 [==============================] - 3s 33ms/step - loss: 0.5167 - accuracy: 0.7859 - val_loss: 0.7200 - val_accuracy: 0.6721
# Epoch 29/50
# 100/100 [==============================] - 3s 35ms/step - loss: 0.5607 - accuracy: 0.7821 - val_loss: 0.5387 - val_accuracy: 0.7541
# Epoch 30/50
# 100/100 [==============================] - 4s 35ms/step - loss: 0.5056 - accuracy: 0.7846 - val_loss: 0.5369 - val_accuracy: 0.7923
# Epoch 31/50
# 100/100 [==============================] - 4s 42ms/step - loss: 0.5227 - accuracy: 0.7834 - val_loss: 0.4578 - val_accuracy: 0.8142
# Epoch 32/50
# 100/100 [==============================] - 3s 33ms/step - loss: 0.5181 - accuracy: 0.7997 - val_loss: 0.4750 - val_accuracy: 0.8142
# Epoch 33/50
# 100/100 [==============================] - 3s 33ms/step - loss: 0.5323 - accuracy: 0.7821 - val_loss: 0.5699 - val_accuracy: 0.7650
# Epoch 34/50
# 100/100 [==============================] - 4s 42ms/step - loss: 0.5011 - accuracy: 0.8010 - val_loss: 0.4571 - val_accuracy: 0.8251
# Epoch 35/50
# 100/100 [==============================] - 3s 32ms/step - loss: 0.4551 - accuracy: 0.8123 - val_loss: 0.5756 - val_accuracy: 0.7814
# Epoch 36/50
# 100/100 [==============================] - 3s 35ms/step - loss: 0.5451 - accuracy: 0.7985 - val_loss: 0.4903 - val_accuracy: 0.7814
# Epoch 37/50
# 100/100 [==============================] - 4s 35ms/step - loss: 0.4707 - accuracy: 0.8300 - val_loss: 0.5242 - val_accuracy: 0.7705
# Epoch 38/50
# 100/100 [==============================] - 3s 35ms/step - loss: 0.5055 - accuracy: 0.7922 - val_loss: 0.4966 - val_accuracy: 0.7869
# Epoch 39/50
# 100/100 [==============================] - 4s 41ms/step - loss: 0.5279 - accuracy: 0.7884 - val_loss: 0.4419 - val_accuracy: 0.8142
# Epoch 40/50
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4858 - accuracy: 0.8149 - val_loss: 0.5527 - val_accuracy: 0.8087
# Epoch 41/50
# 100/100 [==============================] - 4s 35ms/step - loss: 0.4737 - accuracy: 0.8212 - val_loss: 0.4833 - val_accuracy: 0.7923
# Epoch 42/50
# 100/100 [==============================] - 4s 35ms/step - loss: 0.5112 - accuracy: 0.8136 - val_loss: 0.5079 - val_accuracy: 0.8087
# Epoch 43/50
# 100/100 [==============================] - 3s 35ms/step - loss: 0.4889 - accuracy: 0.8060 - val_loss: 0.5435 - val_accuracy: 0.7814
# Epoch 44/50
# 100/100 [==============================] - 4s 35ms/step - loss: 0.4307 - accuracy: 0.8287 - val_loss: 0.4723 - val_accuracy: 0.7923
# Epoch 45/50
# 100/100 [==============================] - 3s 33ms/step - loss: 0.4785 - accuracy: 0.8224 - val_loss: 0.4532 - val_accuracy: 0.7923
# Epoch 46/50
# 100/100 [==============================] - 3s 33ms/step - loss: 0.4440 - accuracy: 0.8338 - val_loss: 0.5117 - val_accuracy: 0.8251
# Epoch 47/50
# 100/100 [==============================] - 4s 38ms/step - loss: 0.4877 - accuracy: 0.8086 - val_loss: 0.4160 - val_accuracy: 0.8525
# Epoch 48/50
# 100/100 [==============================] - 3s 33ms/step - loss: 0.4513 - accuracy: 0.8212 - val_loss: 0.4337 - val_accuracy: 0.8251
# Epoch 49/50
# 100/100 [==============================] - 4s 36ms/step - loss: 0.4473 - accuracy: 0.8212 - val_loss: 0.5646 - val_accuracy: 0.7705
# Epoch 50/50
# 100/100 [==============================] - 3s 35ms/step - loss: 0.4366 - accuracy: 0.8237 - val_loss: 0.4680 - val_accuracy: 0.7923

# %%
gru_model.evaluate(x_train_gru, y_train_gru)

plot_loss_curves(history)
# Out:
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3793 - accuracy: 0.8526

# %%
classes = ["COPD" ,"Bronchiolitis ", "Pneumoina", "URTI", "Healthy"]

preds = gru_model.predict(x_test_gru)
classpreds = [np.argmax(t) for t in preds ]
y_testclass = [np.argmax(t) for t in y_test_gru]
cm = confusion_matrix(y_testclass, classpreds)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
ax = sns.heatmap(cm, cmap='Blues', annot=True, fmt='d', xticklabels=classes, yticklabels=classes)

plt.title('')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)
# Out:
# 3/3 [==============================] - 8s 21ms/step

# %%
print(classification_report(y_testclass, classpreds, target_names=classes))
# Out:
#                 precision    recall  f1-score   support
#
#           COPD       0.96      0.92      0.94        25
# Bronchiolitis        0.60      0.67      0.63         9
#      Pneumoina       0.89      0.80      0.84        10
#           URTI       0.25      0.50      0.33         4
#        Healthy       0.86      0.71      0.77        17
#
#       accuracy                           0.78        65
#      macro avg       0.71      0.72      0.70        65
#   weighted avg       0.83      0.78      0.80        65

# %%
def gru_diagnosis_prediction(test_audio):
    data_x, sampling_rate = librosa.load(test_audio)
    data_x = stretch (data_x,1.2)

    features = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=52).T,axis = 0)

    features = features.reshape(1,52)

    test_pred = gru_model.predict(np.expand_dims(features, axis = 1))
    classpreds = classes[np.argmax(test_pred[0], axis=1)[0]]
    confidence = test_pred.T[test_pred[0].mean(axis=0).argmax()].mean()

    print (classpreds , confidence)

gru_model1 = load_model('gru_model.h5')

def gru_diagnosis_prediction1(test_audio):
    data_x, sampling_rate = librosa.load(test_audio)
    data_x = stretch (data_x,1.2)

    features = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=52).T,axis = 0)

    features = features.reshape(1,52)

    test_pred = gru_model1.predict(np.expand_dims(features, axis = 1))
    classpreds = classes[np.argmax(test_pred[0], axis=1)[0]]
    confidence = test_pred.T[test_pred[0].mean(axis=0).argmax()].mean()

    print (classpreds , confidence)

gru_diagnosis_prediction1('D:/Visual Studio Code/AI Project/input/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/226_1b1_Al_sc_Meditron.wav')
gru_diagnosis_prediction('D:/Visual Studio Code/AI Project/input/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/226_1b1_Al_sc_Meditron.wav')
gru_diagnosis_prediction1('D:/Visual Studio Code/AI Project/input/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/226_1b1_Al_sc_Meditron.wav')
# Out:
# 1/1 [==============================] - 5s 5s/step
# Pneumoina 0.8819862
# 1/1 [==============================] - 0s 29ms/step
# Pneumoina 0.9821768
# 1/1 [==============================] - 0s 29ms/step
# Pneumoina 0.8819862

# %%
val=[]
dir_= 'D:/Visual Studio Code/AI Project/input/respiratory-test/107_2b5_Ar_mc_AKGC417L.wav'
features = 52

soundDir = ''#'/kaggle/input/respiratory-test'
data_x, sampling_rate = librosa.load(dir_+soundDir,res_type='kaiser_fast')
mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T,axis=0)
val.append(mfccs)
val = np.expand_dims(val,axis=1)

# %%
classes[np.argmax(gru_model.predict(val))]
